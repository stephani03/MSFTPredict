# %%
#Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 6
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.preprocessing import MinMaxScaler
# ----> 6 from tensorflow.keras.models import Sequential
#
# File c:\Users\Stephani G\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
#      28 # pylint: disable=g-bad-import-order,protected-access,g-import-not-at-top
# ---> 30 import distutils as _distutils
#      31 import importlib
# ...

# %%
#Dataset
MSFT_Dataset = pd.read_csv(r'C:\Users\Stephani G\Documents\hani\college hani\stupen\tasks\Final Project\MSFT.csv')

# %%
MSFT_Dataset
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-06-04  247.759995  251.649994  247.509995  250.789993  244.464844
# 1    2021-06-07  249.979996  254.089996  249.809998  253.809998  247.408676
# 2    2021-06-08  255.160004  256.010010  252.509995  252.570007  246.199951
# 3    2021-06-09  253.809998  255.529999  253.210007  253.589996  247.194229
# 4    2021-06-10  254.289993  257.459991  253.669998  257.239990  250.752167
# ..          ...         ...         ...         ...         ...         ...
# 749  2024-05-28  429.630005  430.820007  426.600006  430.320007  430.320007
# 750  2024-05-29  425.690002  430.940002  425.690002  429.170013  429.170013
# 751  2024-05-30  424.299988  424.299988  414.239990  414.670013  414.670013
# 752  2024-05-31  416.750000  416.750000  404.510010  415.130005  415.130005
# 753  2024-06-03  415.529999  416.429993  408.920013  413.519989  413.519989
#
#        Volume
# 0    25281100
# 1    23079200
# ...

# %%
#Membagi Data Training dan Data Test
DataTest = MSFT_Dataset.iloc[:,1:2].values
DataTrain = DataTest[:len(DataTest)-50,0]

# %%
#Standarisasi Data
scaler = MinMaxScaler(feature_range=(0,1))
DataTrain_scaled = DataTrain.reshape(-1,1)
DataTrain_scaled = scaler.fit_transform(DataTrain_scaled)
print(DataTrain_scaled)
# Out:
# [[0.14231201]
#  [0.15276991]
#  [0.17717168]
#  [0.17081212]
#  [0.17307327]
#  [0.19050306]
#  [0.19007911]
#  [0.19888821]
#  [0.19714525]
#  [0.18145848]
#  [0.19822878]
#  [0.19912383]
#  [0.21278501]
#  [0.22818914]
#  [0.22899004]
#  [0.22931982]
#  [0.22913135]
#  [0.24175615]
#  [0.25032977]
#  [0.24524207]
#  [0.26036371]
#  [0.28490673]
#  [0.29136045]
#  [0.27958355]
#  [0.27402488]
#  [0.29022991]
#  [0.2825042 ]
#  [0.30525724]
#  [0.30360845]
#  [0.30393824]
#  [0.28914639]
#  [0.28490673]
#  [0.28900507]
#  [0.31227623]
#  [0.32890521]
#  [0.33658377]
#  [0.33860936]
#  [0.33653661]
#  [0.32358202]
#  [0.31854162]
#  [0.32414729]
#  [0.31971931]
#  [0.32348786]
#  [0.32659698]
#  [0.33427554]
#  [0.34011684]
#  [0.33564156]
#  [0.32815147]
#  [0.32541929]
#  [0.33884499]
#  [0.35632186]
#  [0.35255331]
#  [0.35090452]
#  [0.33512344]
#  [0.38708312]
#  [0.40371209]
#  [0.41205009]
#  [0.40865834]
#  [0.39306573]
#  [0.38364421]
#  [0.39367815]
#  [0.40922374]
# ...

# %%
#Membuat data latih menggunakan algoritma
x_train = []
y_train = []
for i in range(120,len(DataTrain_scaled)):
    x_train.append(DataTrain_scaled[i-120:i,0])
    y_train.append(DataTrain_scaled[i,0])

x_train,y_train = np.array(x_train),np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
